# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
spotify = pd.read_csv('spotify.csv')
spotify
# Out:
#     Unnamed: 0           artist  \
# 0            0       The Weeknd
# 1            1      Tones And I
# 2            2      Roddy Ricch
# 3            3        SAINt JHN
# 4            4         Dua Lipa
# 5            5           DaBaby
# 6            6     Harry Styles
# 7            7            Powfu
# 8            8    Trevor Daniel
# 9            9    Lewis Capaldi
# 10          10          KAROL G
# 11          11   Arizona Zervas
# 12          12      Post Malone
# 13          13        Lil Mosey
# 14          14    Justin Bieber
# 15          15            Drake
# 16          16    Lewis Capaldi
# 17          17         Doja Cat
# 18          18         Maroon 5
# 19          19           Future
# 20          20        Jawsh 685
# 21          21     Harry Styles
# 22          22            Topic
# 23          23         24kGoldn
# 24          24    Billie Eilish
# 25          25     Shawn Mendes
# 26          26    Billie Eilish
# 27          27          Cardi B
# ...

# %% [markdown]
# Все поля таблицы данных

# %%
spotify.columns
# Out:
# Index(['Unnamed: 0', 'artist', 'album', 'track_name', 'track_id', 'energy',
#        'danceability', 'key', 'loudness', 'acousticness', 'speechiness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms',
#        'genre'],
#       dtype='object')

# %%
Общее количество полей

# %%
len(spotify)
# Out:
# 50

# %%
Вывел с помощью сортировки первых 10 артистов и их данные

# %%
spotify.sort_values(by=['artist'], ascending=True).head(10)
# Out:
#     Unnamed: 0           artist                                     album  \
# 23          23         24kGoldn                    Mood (feat. iann dior)
# 46          46    Ariana Grande                              Stuck with U
# 11          11   Arizona Zervas                                   ROXANNE
# 33          33            BENEE                                   Hey u x
# 32          32              BTS                Dynamite (DayTime Version)
# 43          43        Bad Bunny                                  YHLQMDLG
# 26          26    Billie Eilish  WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?
# 24          24    Billie Eilish                       everything i wanted
# 44          44    Billie Eilish                      lovely (with Khalid)
# 41          41  Black Eyed Peas                               Translation
#
#                            track_name                track_id  energy  \
# 23             Mood (feat. iann dior)  3tjFYV6RSFtuktYl3ZtYcq   0.722
# ...

# %% [markdown]
# Отобразил последнии 10 полей данных

# %%
spotify.loc[40:50]
# Out:
#     Unnamed: 0           artist  \
# 40          40     Travis Scott
# 41          41  Black Eyed Peas
# 42          42       THE SCOTTS
# 43          43        Bad Bunny
# 44          44    Billie Eilish
# 45          45       Juice WRLD
# 46          46    Ariana Grande
# 47          47          JP Saxe
# 48          48         Dua Lipa
# 49          49     Travis Scott
#
#                                              album  \
# 40                 Birds In The Trap Sing McKnight
# 41                                     Translation
# 42                                      THE SCOTTS
# 43                                        YHLQMDLG
# 44                            lovely (with Khalid)
# 45                         Goodbye & Good Riddance
# 46                                    Stuck with U
# 47  If the World Was Ending (feat. Julia Michaels)
# 48                                Future Nostalgia
# 49                                      ASTROWORLD
#
# ...

# %%
Вывел количество жанров музыки и разделил их с помощью круговой диаграммы

# %%
spotify.groupby('genre').size().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='None'>

# %% [markdown]
# Из преведенной диаграммы мы видим, что наиболее популярными являются жанры: 'Hip-Hop/Rap
# ' и 'Pop'
